# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 22.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov8s.pt")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dpath = '/content/drive/MyDrive/archive/data.yaml'

# %%
results = model.train(data=dpath,
epochs=80,
imgsz=416)
# Out:
# Ultralytics 8.4.90 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !zip -r /content/model1.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/predict/ (stored 0%)
#   adding: content/runs/detect/predict/images.jpg (deflated 5%)
#   adding: content/runs/detect/predict/corn leaf.jpg (deflated 3%)
#   adding: content/runs/detect/predict/Soybean_rust.jpg (deflated 0%)
#   adding: content/runs/detect/predict/strawberry leaf.jpg (deflated 2%)
#   adding: content/runs/detect/predict/straw.jpg (deflated 2%)
#   adding: content/runs/detect/val-3/ (stored 0%)
#   adding: content/runs/detect/val-3/BoxPR_curve.png (deflated 10%)
#   adding: content/runs/detect/val-3/val_batch0_labels.jpg (deflated 8%)
#   adding: content/runs/detect/val-3/val_batch2_labels.jpg (deflated 7%)
#   adding: content/runs/detect/val-3/val_batch2_pred.jpg (deflated 7%)
#   adding: content/runs/detect/val-3/val_batch1_labels.jpg (deflated 8%)
#   adding: content/runs/detect/val-3/BoxF1_curve.png (deflated 10%)
# ...

# %%
from google.colab import files
files.download('/content/model1.zip')

# %%
# !yolo detect val model=runs/detect/train/weights/best.pt data=/content/drive/MyDrive/archive/data.yaml split=test
# Out:
# Ultralytics 8.4.90 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,137,194 parameters, 0 gradients, 28.5 GFLOPs
# WARNING ⚠️ val: Slow image access detected (ping: 1.1±0.7 ms, read: 0.1±0.0 MB/s, size: 34.1 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /content/drive/MyDrive/archive/test/labels... 239 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 239/239 1.8it/s 2:12
# val: New cache created: /content/drive/MyDrive/archive/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 4.8it/s 3.1s
#                    all        239        454      0.617      0.581      0.615      0.479
#        Apple Scab Leaf         10         13      0.475      0.692      0.647      0.502
# ...

# %%
mymodel = YOLO("/content/runs/detect/train/weights/best.pt")

# %%
mymodel.predict(source = '/content/images.jpg',save = True ,imgsz = 640)
# Out:
# image 1/1 /content/images.jpg: 640x448 1 Apple Scab Leaf, 46.7ms
# Speed: 2.5ms preprocess, 46.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to /content/runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
mymodel.predict(source = '/content/corn leaf.jpg',save = True ,imgsz = 640)
# Out:
# image 1/1 /content/corn leaf.jpg: 640x480 2 Corn rust leafs, 49.0ms
# Speed: 2.9ms preprocess, 49.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
mymodel.predict(source = '/content/Soybean_rust.jpg',save = True ,imgsz = 640)
# Out:
# image 1/1 /content/Soybean_rust.jpg: 480x640 1 Blueberry leaf, 3 Corn rust leafs, 45.2ms
# Speed: 2.1ms preprocess, 45.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /content/runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
mymodel.predict(source = '/content/strawberry leaf.jpg',save = True ,imgsz = 640)
# Out:
# image 1/1 /content/strawberry leaf.jpg: 448x640 1 Tomato Septoria leaf spot, 1 Tomato leaf late blight, 46.2ms
# Speed: 2.9ms preprocess, 46.2ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
mymodel.predict(source = '/content/straw.jpg',save = True ,imgsz = 640)
# Out:
# image 1/1 /content/straw.jpg: 480x640 3 Strawberry leafs, 1 Tomato Septoria leaf spot, 13.8ms
# Speed: 2.6ms preprocess, 13.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /content/runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...
